# %% [markdown]
# <a href="https://colab.research.google.com/github/camilanicola/projetos_alura_classificacao/blob/main/intro_machine_learning_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

uri = "https://gist.githubusercontent.com/guilhermesilveira/4d1d4a16ccbf6ea4e0a64a38a24ec884/raw/afd05cb0c796d18f3f5a6537053ded308ba94bf7/car-prices.csv"
dados = pd.read_csv(uri)
dados.head()
# Out:
#    Unnamed: 0  mileage_per_year  model_year      price sold
# 0           0             21801        2000   30941.02  yes
# 1           1              7843        1998   40557.96  yes
# 2           2              7109        2006   89627.50   no
# 3           3             26823        2015   95276.14   no
# 4           4              7935        2014  117384.68  yes

# %%
mapa={
    "mileage_per_year":"milhagem/ano",
    "model_year":"ano_modelo",
    "price":"preco",
    "sold":"vendido"
}
dados=dados.rename(columns=mapa)
dados.head()
# Out:
#    Unnamed: 0  milhagem/ano  ano_modelo      preco vendido
# 0           0         21801        2000   30941.02     yes
# 1           1          7843        1998   40557.96     yes
# 2           2          7109        2006   89627.50      no
# 3           3         26823        2015   95276.14      no
# 4           4          7935        2014  117384.68     yes

# %%
troca={
    "no":0,
    "yes":1
}
dados.vendido=dados.vendido.map(troca)
dados.head()
# Out:
#    Unnamed: 0  milhagem/ano  ano_modelo      preco  vendido
# 0           0         21801        2000   30941.02        1
# 1           1          7843        1998   40557.96        1
# 2           2          7109        2006   89627.50        0
# 3           3         26823        2015   95276.14        0
# 4           4          7935        2014  117384.68        1

# %%
from datetime import datetime
ano_atual= datetime.today().year
dados['idade_modelo']=ano_atual - dados['ano_modelo']

# %%
dados['km_por_ano']=dados['milhagem/ano']*1.6934

# %%
dados=dados.drop(columns=['Unnamed: 0','milhagem/ano','ano_modelo',],axis=1)

# %%
x=dados[['preco','idade_modelo','km_por_ano']]
y=dados['vendido']

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score

train_x,test_x,train_y,test_y=train_test_split(x,y,random_state=42,test_size=0.25, stratify=y)
model=LinearSVC()
model.fit(train_x,train_y)
# Out:
# SVC()

# %%
predicted=model.predict(test_x)
accuracy=accuracy_score(test_y,predicted)
print("%.2f%%" % accuracy)
